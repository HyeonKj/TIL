# %% [markdown]
# ## IMDB 데이터셋
#
# #### 인터넷 영화 데이터 베이스
# #### 리뷰 :50,000개
# #### 훈련 데이터 : 25,000개(긍정:50%, 부정:50%)
# #### 테스트 데이터 : 25,000개

# %%
from tensorflow import keras
import pandas as pd

keras.__version__
# Out:
# '2.8.0'

# %%
from keras.datasets import imdb
(train_data, train_labels),(train_data, test_labels)=imdb.load_data(num_words=10000)
#2진분류문제 (영화댓글이 긍정이냐 부정이냐)

# %%
train_labels
# Out:
# array([1, 0, 0, ..., 0, 1, 0], dtype=int64)

# %%
train_data.shape, train_labels.shape
# Out:
# ((25000,), (25000,))

# %%
import pandas as pd

train_data
# Out:
# array([list([1, 591, 202, 14, 31, 6, 717, 10, 10, 2, 2, 5, 4, 360, 7, 4, 177, 5760, 394, 354, 4, 123, 9, 1035, 1035, 1035, 10, 10, 13, 92, 124, 89, 488, 7944, 100, 28, 1668, 14, 31, 23, 27, 7479, 29, 220, 468, 8, 124, 14, 286, 170, 8, 157, 46, 5, 27, 239, 16, 179, 2, 38, 32, 25, 7944, 451, 202, 14, 6, 717]),
# ...

# %%
train_data_df = pd.DataFrame(train_data, train_labels)
train_labels_df = pd.DataFrame(train_labels)

movie_df = pd.DataFrame(train_data_df)
movie_df.columns = ['train_data']
movie_df['train_labels']=train_labels_df
movie_df
# Out:
#                                            train_data  train_labels
# 1   [1, 591, 202, 14, 31, 6, 717, 10, 10, 2, 2, 5,...             0
# 0   [1, 14, 22, 3443, 6, 176, 7, 5063, 88, 12, 267...             1
# 0   [1, 111, 748, 4368, 1133, 2, 2, 4, 87, 1551, 1...             1
# 1   [1, 13, 1228, 119, 14, 552, 7, 20, 190, 14, 58...             0
# 0   [1, 40, 49, 85, 84, 1040, 146, 6, 783, 254, 43...             1
# ..                                                ...           ...
# 1   [1, 4, 274, 9, 128, 74, 4, 22, 669, 88, 7, 4, ...             0
# 0   [1, 4, 9212, 2293, 8, 126, 67, 6, 4210, 1494, ...             1
# 0   [1, 13, 1408, 15, 8, 135, 14, 9, 35, 32, 46, 3...             1
# 1   [1, 11, 119, 241, 9, 4, 840, 20, 12, 468, 15, ...             0
# 0   [1, 6, 52, 7465, 430, 22, 9, 220, 2594, 8, 28,...             1
#
# [25000 rows x 2 columns]

# %%
movie_df.shape
# Out:
# (25000, 2)

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25000 entries, 1 to 0
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   train_data    25000 non-null  object
#  1   train_labels  25000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 585.9+ KB

# %%
movie_df.dtypes
# Out:
# train_data      object
# train_labels     int64
# dtype: object

# %%
movie_df.iloc[:,0]
# Out:
# 1    [1, 591, 202, 14, 31, 6, 717, 10, 10, 2, 2, 5,...
# 0    [1, 14, 22, 3443, 6, 176, 7, 5063, 88, 12, 267...
# 0    [1, 111, 748, 4368, 1133, 2, 2, 4, 87, 1551, 1...
# 1    [1, 13, 1228, 119, 14, 552, 7, 20, 190, 14, 58...
# 0    [1, 40, 49, 85, 84, 1040, 146, 6, 783, 254, 43...
#                            ...
# 1    [1, 4, 274, 9, 128, 74, 4, 22, 669, 88, 7, 4, ...
# 0    [1, 4, 9212, 2293, 8, 126, 67, 6, 4210, 1494, ...
# 0    [1, 13, 1408, 15, 8, 135, 14, 9, 35, 32, 46, 3...
# 1    [1, 11, 119, 241, 9, 4, 840, 20, 12, 468, 15, ...
# 0    [1, 6, 52, 7465, 430, 22, 9, 220, 2594, 8, 28,...
# Name: train_data, Length: 25000, dtype: object

# %%
movie_df[:]['train_data']
#위와 같은 방법
# Out:
# 1    [1, 591, 202, 14, 31, 6, 717, 10, 10, 2, 2, 5,...
# 0    [1, 14, 22, 3443, 6, 176, 7, 5063, 88, 12, 267...
# 0    [1, 111, 748, 4368, 1133, 2, 2, 4, 87, 1551, 1...
# 1    [1, 13, 1228, 119, 14, 552, 7, 20, 190, 14, 58...
# 0    [1, 40, 49, 85, 84, 1040, 146, 6, 783, 254, 43...
#                            ...
# 1    [1, 4, 274, 9, 128, 74, 4, 22, 669, 88, 7, 4, ...
# 0    [1, 4, 9212, 2293, 8, 126, 67, 6, 4210, 1494, ...
# 0    [1, 13, 1408, 15, 8, 135, 14, 9, 35, 32, 46, 3...
# 1    [1, 11, 119, 241, 9, 4, 840, 20, 12, 468, 15, ...
# 0    [1, 6, 52, 7465, 430, 22, 9, 220, 2594, 8, 28,...
# Name: train_data, Length: 25000, dtype: object

# %%
movie_df
# Out:
#                                            train_data  train_labels
# 1   [1, 591, 202, 14, 31, 6, 717, 10, 10, 2, 2, 5,...             0
# 0   [1, 14, 22, 3443, 6, 176, 7, 5063, 88, 12, 267...             1
# 0   [1, 111, 748, 4368, 1133, 2, 2, 4, 87, 1551, 1...             1
# 1   [1, 13, 1228, 119, 14, 552, 7, 20, 190, 14, 58...             0
# 0   [1, 40, 49, 85, 84, 1040, 146, 6, 783, 254, 43...             1
# ..                                                ...           ...
# 1   [1, 4, 274, 9, 128, 74, 4, 22, 669, 88, 7, 4, ...             0
# 0   [1, 4, 9212, 2293, 8, 126, 67, 6, 4210, 1494, ...             1
# 0   [1, 13, 1408, 15, 8, 135, 14, 9, 35, 32, 46, 3...             1
# 1   [1, 11, 119, 241, 9, 4, 840, 20, 12, 468, 15, ...             0
# 0   [1, 6, 52, 7465, 430, 22, 9, 220, 2594, 8, 28,...             1
#
# [25000 rows x 2 columns]

# %%
train_labels[0]
# Out:
# 1

# %%
movie_df.isnull().sum() # 결측값 확인. 무
# Out:
# train_data      0
# train_labels    0
# dtype: int64

# %%
movie_df.max()
# Out:
# train_data      [1, 9927, 2, 9, 6, 686, 19, 6, 117, 1056, 37, ...
# train_labels                                                    1
# dtype: object

# %%
max([max(sequence) for sequence in train_data])
# Out:
# 9999

# %%
[max(sequence) for sequence in train_data]
# Out:
# [7944,
#  8463,
#  9909,
#  9185,
#  4386,
#  9493,
#  9653,
#  8408,
#  9687,
#  9658,
#  7999,
#  5822,
#  9985,
#  9945,
#  9541,
#  9364,
#  9801,
#  7907,
#  7767,
#  9823,
#  9320,
#  8695,
#  9692,
#  3570,
#  9550,
#  9752,
#  9911,
#  3799,
#  9830,
#  9474,
#  9996,
#  9994,
#  6849,
#  9808,
#  9951,
#  9940,
#  7813,
#  9206,
#  8194,
#  8834,
#  9633,
#  9783,
#  9938,
#  9912,
#  9915,
#  9493,
#  7472,
#  8046,
#  9432,
#  9504,
#  9395,
#  6005,
#  6080,
#  5414,
#  9899,
#  9901,
#  6769,
#  7584,
#  9135,
#  8893,
#  8634,
#  9923,
#  7812,
#  9594,
#  9866,
#  8170,
#  8450,
#  7747,
#  9699,
#  4051,
#  8401,
#  9969,
#  7239,
#  9690,
#  9418,
#  9848,
#  9834,
#  8529,
#  9557,
#  3942,
#  7396,
#  8959,
#  9599,
#  9107,
#  9144,
#  9747,
#  3998,
#  9785,
#  9516,
#  9949,
#  9597,
#  7015,
#  8538,
#  9964,
#  9888,
#  8906,
#  9210,
#  9860,
#  8908,
#  9787,
#  9665,
#  9828,
#  9968,
#  9719,
#  4141,
#  8852,
#  8647,
#  6623,
#  9977,
#  9192,
#  8137,
# ...

# %%
len([max(sequence) for sequence in train_data])
# Out:
# 25000

# %%
train_data[1]
# Out:
# [1,
#  14,
#  22,
#  3443,
#  6,
#  176,
#  7,
#  5063,
#  88,
#  12,
#  2679,
#  23,
#  1310,
#  5,
#  109,
#  943,
#  4,
#  114,
#  9,
#  55,
#  606,
#  5,
#  111,
#  7,
#  4,
#  139,
#  193,
#  273,
#  23,
#  4,
#  172,
#  270,
#  11,
#  7216,
#  2,
#  4,
#  8463,
#  2801,
#  109,
#  1603,
#  21,
#  4,
#  22,
#  3861,
#  8,
#  6,
#  1193,
#  1330,
#  10,
#  10,
#  4,
#  105,
#  987,
#  35,
#  841,
#  2,
#  19,
#  861,
#  1074,
#  5,
#  1987,
#  2,
#  45,
#  55,
#  221,
#  15,
#  670,
#  5304,
#  526,
#  14,
#  1069,
#  4,
#  405,
#  5,
#  2438,
#  7,
#  27,
#  85,
#  108,
#  131,
#  4,
#  5045,
#  5304,
#  3884,
#  405,
#  9,
#  3523,
#  133,
#  5,
#  50,
#  13,
#  104,
#  51,
#  66,
#  166,
#  14,
#  22,
#  157,
#  9,
#  4,
#  530,
#  239,
#  34,
#  8463,
#  2801,
#  45,
#  407,
#  31,
#  7,
#  41,
#  3778,
#  105,
#  21,
#  59,
#  299,
#  12,
#  38,
#  950,
#  5,
#  4521,
#  15,
#  45,
#  629,
#  488,
#  2733,
#  127,
#  6,
#  52,
#  292,
#  17,
#  4,
#  6936,
#  185,
#  132,
# ...

# %%
for i in train_data[1]:
    print(i)
# Out:
# 1
# 14
# 22
# 3443
# 6
# 176
# 7
# 5063
# 88
# 12
# 2679
# 23
# 1310
# 5
# 109
# 943
# 4
# 114
# 9
# 55
# 606
# 5
# 111
# 7
# 4
# 139
# 193
# 273
# 23
# 4
# 172
# 270
# 11
# 7216
# 2
# 4
# 8463
# 2801
# 109
# 1603
# 21
# 4
# 22
# 3861
# 8
# 6
# 1193
# 1330
# 10
# 10
# 4
# 105
# 987
# 35
# 841
# 2
# 19
# 861
# 1074
# 5
# 1987
# 2
# 45
# 55
# 221
# 15
# 670
# 5304
# 526
# 14
# 1069
# 4
# 405
# 5
# 2438
# 7
# 27
# 85
# 108
# 131
# 4
# 5045
# 5304
# 3884
# 405
# 9
# 3523
# 133
# 5
# 50
# 13
# 104
# 51
# 66
# 166
# 14
# 22
# 157
# 9
# 4
# 530
# 239
# 34
# 8463
# 2801
# 45
# 407
# 31
# 7
# 41
# 3778
# 105
# 21
# 59
# 299
# 12
# 38
# 950
# 5
# 4521
# 15
# 45
# 629
# 488
# 2733
# 127
# 6
# 52
# 292
# 17
# 4
# 6936
# 185
# 132
# 1988
# 5304
# 1799
# 488
# 2693
# 47
# 6
# 392
# 173
# 4
# 2
# 4378
# 270
# 2352
# 4
# 1500
# 7
# 4
# 65
# 55
# 73
# 11
# 346
# 14
# 20
# 9
# 6
# 976
# 2078
# 7
# 5293
# 861
# 2
# 5
# 4182
# 30
# 3127
# 2
# 56
# 4
# 841
# 5
# 990
# 692
# 8
# 4
# 1669
# 398
# 229
# 10
# ...

# %%
word_index = imdb.get_word_index()
word_index
# Out:
# {'fawn': 34701,
#  'tsukino': 52006,
#  'nunnery': 52007,
#  'sonja': 16816,
#  'vani': 63951,
#  'woods': 1408,
#  'spiders': 16115,
#  'hanging': 2345,
#  'woody': 2289,
#  'trawling': 52008,
#  "hold's": 52009,
#  'comically': 11307,
#  'localized': 40830,
#  'disobeying': 30568,
#  "'royale": 52010,
#  "harpo's": 40831,
#  'canet': 52011,
#  'aileen': 19313,
#  'acurately': 52012,
#  "diplomat's": 52013,
#  'rickman': 25242,
#  'arranged': 6746,
#  'rumbustious': 52014,
#  'familiarness': 52015,
#  "spider'": 52016,
#  'hahahah': 68804,
#  "wood'": 52017,
#  'transvestism': 40833,
#  "hangin'": 34702,
#  'bringing': 2338,
#  'seamier': 40834,
#  'wooded': 34703,
#  'bravora': 52018,
#  'grueling': 16817,
#  'wooden': 1636,
#  'wednesday': 16818,
#  "'prix": 52019,
#  'altagracia': 34704,
#  'circuitry': 52020,
#  'crotch': 11585,
#  'busybody': 57766,
#  "tart'n'tangy": 52021,
#  'burgade': 14129,
#  'thrace': 52023,
#  "tom's": 11038,
#  'snuggles': 52025,
# ...

# %%
{v:k for k, v in word_index.items()}
#리스트 컴프레헨션
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
reverse_word_index
# Out:
# {34701: 'fawn',
#  52006: 'tsukino',
#  52007: 'nunnery',
#  16816: 'sonja',
#  63951: 'vani',
#  1408: 'woods',
#  16115: 'spiders',
#  2345: 'hanging',
#  2289: 'woody',
#  52008: 'trawling',
#  52009: "hold's",
#  11307: 'comically',
#  40830: 'localized',
#  30568: 'disobeying',
#  52010: "'royale",
#  40831: "harpo's",
#  52011: 'canet',
#  19313: 'aileen',
#  52012: 'acurately',
#  52013: "diplomat's",
#  25242: 'rickman',
#  6746: 'arranged',
#  52014: 'rumbustious',
#  52015: 'familiarness',
#  52016: "spider'",
#  68804: 'hahahah',
#  52017: "wood'",
#  40833: 'transvestism',
#  34702: "hangin'",
#  2338: 'bringing',
#  40834: 'seamier',
#  34703: 'wooded',
#  52018: 'bravora',
#  16817: 'grueling',
#  1636: 'wooden',
#  16818: 'wednesday',
#  52019: "'prix",
#  34704: 'altagracia',
#  52020: 'circuitry',
#  11585: 'crotch',
#  57766: 'busybody',
#  52021: "tart'n'tangy",
#  14129: 'burgade',
#  52023: 'thrace',
#  11038: "tom's",
#  52025: 'snuggles',
# ...

# %%
len(reverse_word_index)
# Out:
# 88584

# %%
sorted(word_index)
# Out:
# ['\x08\x08\x08\x08a',
#  '\x10own',
#  "'",
#  "''",
#  "''a",
#  "''after",
#  "''bad",
#  "''cannibal",
#  "''clients''",
#  "''dark''",
#  "''empire",
#  "''family",
#  "''gaslight''",
#  "''heart''",
#  "''high",
#  "''holy",
#  "''human''",
#  "''humans''",
#  "''i'm",
#  "''if",
#  "''inuyasha''",
#  "''little''",
#  "''maison",
#  "''ned''",
#  "''negative''",
#  "''nice",
#  "''oh",
#  "''on",
#  "''oversexed''",
#  "''peeping",
#  "''professionals''",
#  "''ranma",
#  "''raptors''",
#  "''return",
#  "''saint",
#  "''scarface''",
#  "''sea",
#  "''talent",
#  "''terrorists''",
#  "''the",
#  "''their",
#  "''this",
#  "''thunderball",
#  "''troubled''",
#  "''unpleasant",
#  "''villain",
#  "''voyeur''",
#  "''we're",
#  "''while''",
#  "''your",
#  "''zero",
#  "'0",
#  "'00s",
#  "'01",
#  "'02",
#  "'03",
#  "'04",
#  "'05",
#  "'06",
#  "'07",
#  "'08",
#  "'1",
#  "'1'",
#  "'10",
#  "'10'",
#  "'12",
#  "'1408'",
#  "'1902'",
#  "'1909",
#  "'1940'",
#  "'2'",
# ...

# %%
train_data[17]
# Out:
# [1,
#  1659,
#  2,
#  3717,
#  9,
#  6,
#  2343,
#  37,
#  456,
#  18,
#  27,
#  292,
#  33,
#  52,
#  2,
#  6,
#  392,
#  21,
#  2575,
#  3243,
#  2,
#  759,
#  137,
#  27,
#  2069,
#  2,
#  5778,
#  82,
#  495,
#  50,
#  21,
#  583,
#  2,
#  686,
#  2971,
#  7907,
#  8,
#  27,
#  292,
#  240,
#  50,
#  88,
#  29,
#  2507,
#  2730,
#  4,
#  519,
#  7,
#  27,
#  1750,
#  443,
#  2,
#  2,
#  5,
#  47,
#  8,
#  2988,
#  278,
#  8,
#  990,
#  4,
#  2,
#  54,
#  2,
#  2,
#  6,
#  2,
#  702,
#  2020,
#  3629,
#  2013,
#  638,
#  4,
#  890,
#  12,
#  272,
#  40,
#  52,
#  2,
#  9,
#  479,
#  366,
#  1659,
#  2,
#  6,
#  1003,
#  2,
#  15,
#  961,
#  3103,
#  7,
#  162,
#  7781,
#  8,
#  68,
#  1312,
#  190,
#  4,
#  2,
#  3038,
#  7,
#  2,
#  2,
#  3199,
#  6579,
#  9,
#  2930,
#  8,
#  79,
#  27,
#  957,
#  23,
#  4,
#  2,
#  5,
#  276,
#  52,
#  2,
#  46,
#  7,
#  970,
#  2086,
#  1659,
#  5,
#  2,
#  215,
#  2232,
#  2,
#  2,
#  2,
#  4,
#  3446,
#  5641,
#  702,
#  1644,
#  7045,
# ...

# %%
reverse_word_index[1], reverse_word_index[33], reverse_word_index[4]
# Out:
# ('the', 'they', 'of')

# %%
decoded_reivew = [reverse_word_index.get(i - 3, '?') for i in train_data[17]]

# %%
decoded_reivew
# Out:
# ['?',
#  'ed',
#  '?',
#  'mitchell',
#  'is',
#  'a',
#  'teenager',
#  'who',
#  'lives',
#  'for',
#  'his',
#  'job',
#  'at',
#  'good',
#  '?',
#  'a',
#  'small',
#  'but',
#  'friendly',
#  'neighborhood',
#  '?',
#  'stand',
#  'while',
#  'his',
#  'buddy',
#  '?',
#  'thompson',
#  'also',
#  'works',
#  'there',
#  'but',
#  'lack',
#  '?',
#  'single',
#  'minded',
#  'devotion',
#  'to',
#  'his',
#  'job',
#  "he's",
#  'there',
#  'because',
#  'he',
#  'accidentally',
#  'destroyed',
#  'the',
#  'car',
#  'of',
#  'his',
#  'teacher',
#  'mr',
#  '?',
#  '?',
#  'and',
#  'has',
#  'to',
#  'raise',
#  'money',
#  'to',
#  'pay',
#  'the',
#  '?',
#  'when',
#  '?',
#  '?',
#  'a',
#  '?',
#  'fast',
#  'foot',
#  'chain',
#  'opens',
#  'across',
#  'the',
#  'street',
#  'it',
#  'looks',
#  'like',
#  'good',
#  '?',
#  'is',
#  'history',
#  'until',
#  'ed',
#  '?',
#  'a',
#  'secret',
#  '?',
#  'that',
#  'brings',
#  'hundreds',
#  'of',
#  'new',
# ...

# %%
# 0 1 2 는 '패딩',' 문서시작','사전에 없음'을 위한 인덱스이므로 3을 뺍니다. 
decoded_review = ' '.join([reverse_word_index.get(i -3, '?') for i in train_data[17]])
decoded_review
# Out:
# "? ed ? mitchell is a teenager who lives for his job at good ? a small but friendly neighborhood ? stand while his buddy ? thompson also works there but lack ? single minded devotion to his job he's there because he accidentally destroyed the car of his teacher mr ? ? and has to raise money to pay the ? when ? ? a ? fast foot chain opens across the street it looks like good ? is history until ed ? a secret ? that brings hundreds of new customers to their door however the ? manager of ? ? kurt jan is determined to get his hands on the ? and put good ? out of business meanwhile ed and ? must rescue ? ? ? the world's oldest fast food employee from the demented hills asylum and ed might just find love with ? jackson if he could take his mind off the ? long enough to pay attention to her good ? is a comedy directed for kids decent story acting and overall a pretty harmless kids movie"

# %%
reverse_word_index[30], reverse_word_index[1], reverse_word_index[11], reverse_word_index[17]
# Out:
# ('at', 'the', 'this', 'movie')

# %%
reverse_word_index[2], reverse_word_index[1], reverse_word_index[3], reverse_word_index[4]
# Out:
# ('and', 'the', 'a', 'of')

# %%
decoded_review = ' '.join([reverse_word_index.get(i -3, '?') for i in train_data[24000]])
decoded_review
# Out:
# "? there were only two redeeming features about this movie the beauty of ? and its architecture and the way they depicted the transformation from human form to wolf form forget about the plot or storyline from the book they're completely absent from this movie in fact about the only things carried over from the book are the names of the main players even then you'll barely recognize the characterizations if the film makers had made a good movie even though unrelated to the book i wouldn't have been so disappointed unfortunately they did not the plot and storyline are typical of low budget horror flicks the acting is wooden and the directorial efforts mundane oh yes the way the bow to their leader is pure ? i suppose a nod of recognition is due for the animal ? the wolves were beautiful animals and well managed in their roles"

# %%
type(reverse_word_index)
# Out:
# dict

# %% [markdown]
# ##  데이터 준비

# %%
import numpy as np
#[1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, ...	
def vectorize_sequences(sequences, dimension=10000):
    print(len(sequences))
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
        print()
    return results


# 훈련 데이터를 벡터로 변환
x_train = vectorize_sequences(train_data).astype('float32')
# 테스트 데이터를 벡터로 변환
x_test = vectorize_sequences(test_data).astype('float32')

print(x_train[0])
print(x_test[1])
# Out:
# 25000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29516/3470605459.py in <module>
#      13 x_train = vectorize_sequences(train_data).astype('float32')
#      14 # 테스트 데이터를 벡터로 변환
# ---> 15 x_test = vectorize_sequences(test_data).astype('float32')
#      16
#      17 print(x_train[0])
#
# NameError: name 'test_data' is not defined

# %%
x_train[0]
# Out:
# array([0., 1., 1., ..., 0., 0., 0.], dtype=float32)

# %%
sequence = [1,3]
results = np.zeros((3,5))
results[0,sequence]=1.

results[0]
# Out:
# array([0., 1., 0., 1., 0.])

# %%
y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# %%
y_train
# Out:
# array([1., 0., 0., ..., 0., 1., 0.], dtype=float32)

# %% [markdown]
# ### 신경망 모델 만들기
# ![3-layer network](https://s3.amazonaws.com/book.keras.io/img/ch3/3_layer_network.png)

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer = 'rmsprop',
              loss = 'binary_crossentropy',
              metrics=['accuracy'])

# %%
from keras import optimizers
from tensorflow.keras import optimizers

model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
from keras import losses
from keras import metrics
from tensorflow.keras import optimizers

model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001),
              loss=losses.binary_crossentropy,
              metrics=[metrics.binary_accuracy])

# %% [markdown]
# # 훈련 검증

# %%
# 모델을 만들어내기 위한 데이터임
x_val = x_train[:10000]
partial_x_train = x_train[10000:]

y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])

history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 30/30 [==============================] - 2s 35ms/step - loss: 0.6934 - acc: 0.5013 - val_loss: 0.6935 - val_acc: 0.5048
# Epoch 2/20
# 30/30 [==============================] - 1s 31ms/step - loss: 0.6789 - acc: 0.5977 - val_loss: 0.6975 - val_acc: 0.4973
# Epoch 3/20
# 30/30 [==============================] - 1s 29ms/step - loss: 0.6477 - acc: 0.6694 - val_loss: 0.7042 - val_acc: 0.5006
# Epoch 4/20
# 30/30 [==============================] - 1s 27ms/step - loss: 0.6079 - acc: 0.7079 - val_loss: 0.7230 - val_acc: 0.4992
# Epoch 5/20
# 30/30 [==============================] - 1s 27ms/step - loss: 0.5659 - acc: 0.7449 - val_loss: 0.7420 - val_acc: 0.5025
# Epoch 6/20
# 30/30 [==============================] - 1s 26ms/step - loss: 0.5215 - acc: 0.7757 - val_loss: 0.7620 - val_acc: 0.5038
# Epoch 7/20
# 30/30 [==============================] - 1s 28ms/step - loss: 0.4802 - acc: 0.7983 - val_loss: 0.7897 - val_acc: 0.5020
# Epoch 8/20
# ...

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['binary_accuracy']
val_acc = history.history['val_binary_accuracy']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29516/3284013940.py in <module>
#       1 loss = history.history['loss']
#       2 val_loss = history.history['val_loss']
# ----> 3 acc = history.history['binary_accuracy']
#       4 val_acc = history.history['val_binary_accuracy']
#
# KeyError: 'binary_accuracy'

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss=history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc)+1)

plt.plot(epochs, loss, 'bo', label='Training loss')

plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29516/1258016397.py in <module>
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 acc = history.history['accuracy']
#       4 val_acc = history.history['val_accuracy']
#       5 loss=history.history['loss']
#
# KeyError: 'accuracy'

# %%
plt.clf()

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
