# %%
import csv
f=open('age.csv')
data=csv.reader(f)
next(data)
a=input()
result=[]
name=input("인구 구조가 알고 싶은 지역의 이름을 입력해 주세요:")
for row in data:
    if name in row[0]:
        for i in row[3:]:
            result.append(int(i))

import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rc('font',family='Malgun Gothic')
plt.title(name+'지역의 인구 구조')
plt.plot(result)
plt.show()
# Out:
# 신도림
# 인구 구조가 알고 싶은 지역의 이름을 입력해 주세요:신도림동

# %%
import matplotlib.pyplot as plt
plt.bar([0,1,2,4,6,10],[1,2,3,5,6,7])
plt.show()

# %%
import matplotlib.pyplot as plt  
import csv
f=open('seoul.csv')
data=csv.reader(f)
next(data)

month=[[],[],[],[],[],[],[],[],[],[],[],[]]

for row in data:
       if row[-1] !='':
           month[int(row[0].split('-')[1])-1].append(float(row[-1]))

plt.boxplot(month)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import csv
f=open('gender.csv')
data=csv.reader(f)
next(data)

m=[]
f=[]

for row in data:
    if '신도림' in row[0]:
        for i in row[3:104]:
            m.append(int(i))
        for i in row[106:]:
            f.append(-int(i))
f.reverse()
import matplotlib.pyplot as plt
plt.barh(range(101),m)
plt.barh(range(101),f)
plt.show()

# %%
import csv
f=open('gender.csv')
data=csv.reader(f)
next(data)

m=[]
f=[]

for row in data:
    if '신도림' in row[0]:
        for i in range(0,101): #101개 0에서부터 100
            m.append(int(row[i+3])) #위치 3부터 시작하기 때문에 +3 !! 
            f.append(int(row[i+106])) #-1위치부터 하면 되는데 106이 0세니까 106더해도됨.

import matplotlib.pyplot as plt
plt.rc('font',family='Malgun Gothic')
plt.title('신도림지역의 남녀 성별 인구 분포')
plt.barh(range(101),m,label='남성')
plt.barh(range(101),f,label='여성')
plt.show()

# %%
import csv
f=open('gender.csv')
data=csv.reader(f)
next(data)

m=[]
f=[]
name=input('찾고 싶은 지역의 이름을 알려주세요.:')

for row in data:
    if name in row[0]:
        for i in range(0,101): #101개 0에서부터 100
            m.append(int(row[i+3])) #위치 3부터 시작하기 때문에 +3 !! 
            f.append(int(row[i+106])) #-1위치부터 하면 되는데 106이 0세니까 106더해도됨.

import matplotlib.pyplot as plt
plt.rc('font',family='Malgun Gothic')
plt.title('지역의 남녀 성별 인구 분포')
plt.barh(range(101),m,label='남성')
plt.barh(range(101),f,label='여성')
plt.legend()
plt.show()
# Out:
# 찾고 싶은 지역의 이름을 알려주세요.:신도림동

# %%
import csv
f=open('gender.csv')
data=csv.reader(f)
next(data)

m=[]
f=[]
name=input('찾고 싶은 지역의 이름을 알려주세요.:')

for row in data:
    if name in row[0]:
        for i in row[3:104]:
            m.append(-int(i))
        for i in row[106:]:
            f.append(int(i))
        break

import matplotlib.pyplot as plt
plt.rc('font',family='Malgun Gothic')
plt.title('지역의 남녀 성별 인구 분포')
plt.barh(range(101),m,label='남성')
plt.barh(range(101),f,label='여성')
plt.legend()
plt.show()
# Out:
# 찾고 싶은 지역의 이름을 알려주세요.:신도림동

# %%
plt.pie([10,20])
plt.show()

# %%
import matplotlib.pyplot as plt
size=[2441,2312,1031,1233]
label=['A형','B형','AB형','O형']
plt.axis('equal')
color=['darkmagenta','deeppink','green','gray']
plt.pie(size,labels=label,autopct='%.1f%%',colors=color,explode=(0,0,0.1,0))
plt.legend()
plt.show()

# %%
import csv

f=open('gender.csv')
data=csv.reader(f)
size=[]
name=input('찾고 싶은 지역의 이름을 알려주세요.:')

for row in data:
    if name in row[0]:
        m=0
        f=0
        for i in range(101):
            m+=int(row[i+3]) #3~103번까지 데이터 더하기
            f+=int(row[i+106]) #106~206번까지 데이터 더하기
        break

size.append(m)
size.append(f)
print(size)

import matplotlib.pyplot as plt
plt.rc('font',family='Malgun Gothic')
plt.axis('equal')
color=['green','gray']
plt.pie(size,labels=label,autopct='%.1f%%',colors=color,explode=(0,0,0.1,0))
plt.legend()
plt.show()
# Out:
# 찾고 싶은 지역의 이름을 알려주세요.:신도림동
# [17517, 18532]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23188/3173822088.py in <module>
#      23 plt.axis('equal')
#      24 color=['green','gray']
# ---> 25 plt.pie(size,labels=label,autopct='%.1f%%',colors=color,explode=(0,0,0.1,0))
#      26 plt.legend()
#      27 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    3004         textprops=None, center=(0, 0), frame=False,
#    3005         rotatelabels=False, *, normalize=None, data=None):
# -> 3006     return gca().pie(
#    3007         x, explode=explode, labels=labels, colors=colors,
# ...

# %%
import csv

f=open('gender.csv')
data=csv.reader(f)
m=[]
f=[]

name=input('궁금한 동네를 입력해주세요.:')


for row in data:
    if name in row[0]:
        for i in range(3,104):
            m.append(int(i.replace(',', '')))
            f.append(int(i.replace(',', ''))) 
        break
import matplotlib.pyplot as plt
plt.plot(m, label='Male')
plt.plot(f, label='Female')
plt.legend()
plt.show()
# Out:
# 궁금한 동네를 입력해주세요.:제주특별자치도
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23188/1232789527.py in <module>
#      12     if name in row[0]:
#      13         for i in range(3,104):
# ---> 14             m.append(int(i.replace(',', '')))
#      15             f.append(int(i.replace(',', '')))
#      16         break
#
# AttributeError: 'int' object has no attribute 'replace'

# %%
import csv

f=open('gender.csv')
data=csv.reader(f)
result=[]
name=input('궁금한 동네를 입력해주세요.:')

for row in data:
    if name in row[0]:
        for i in range(3,104):
            result.append(int(row[i])- int(row[i+103]))
        break
         
import matplotlib.pyplot as plt
plt.bar(range(101),result)
plt.show()
# Out:
# 궁금한 동네를 입력해주세요.:신도림동

# %%
import matplotlib.pyplot as plt 
import random
x=[]
y=[]
size=[]
for i in range(100):
    x.append(random.randint(50,100))
    y.append(random.randint(50,100))
    size.append(random.randint(10,100))

plt.scatter(x,y,s=size,c=size,cmap='ocean')
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt 
import random
x=[]
y=[]
size=[]
for i in range(100):
    x.append(random.randint(50,100))
    y.append(random.randint(50,100))
    size.append(random.randint(10,100))

plt.scatter(x,y,s=size,c=size,cmap='ocean',alpha=0.7)
plt.colorbar()
plt.show()

# %%
import seaborn as sns
titanic=sns.load_dataset('titanic')
print(titanic.head())
print('\n')
print(titanic.info())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
# ...

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set_style('ticks')

fig=plt.figure(figsize=(15,5)) #사이즈 설정 
ax1=fig.add_subplot(1,2,1) #(1,2,3)위치를 나타냄
ax2=fig.add_subplot(1,2,2) 
    
sns.regplot(x='age',
           y='fare',
           data=titanic,
           ax=ax1)

sns.regplot(x='age',
           y='fare',
           data=titanic,
           ax=ax2,
           fit_reg=False)
plt.show()

# %%
fig=plt.figure(figsize=(15,5))
ax1=fig.add_subplot(1,3,1)
ax2=fig.add_subplot(1,3,2)
ax3=fig.add_subplot(1,3,3)

sns.distplot(titanic['fare'],ax=ax1)

sns.distplot(titanic['fare'],hist=False,ax=ax2)

sns.distplot(titanic['fare'],kde=False,ax=ax3)

ax1.set_title('titanic fare - hist/ked')
ax2.set_title('titanic fare - ked')
ax3.set_title('titanic fare - hist')

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
table=titanic.pivot_table(index=['sex'],columns=['class'],aggfunc='size')

sns.heatmap(table,
           annot=True, fmt='d',
           cmap='YlGnBu',
           linewidth=.20,
           cbar=True)
plt.show()

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

titanic=sns.load_dataset('titanic')

sns.set_style('whitegrid')

fig=plt.figure(figsize=(15,5)) #사이즈 설정 
ax1=fig.add_subplot(1,2,1) #(1,2,3)위치를 나타냄 1행, 2열, 1번째, 2번째 ---등
ax2=fig.add_subplot(1,2,2) 

sns.stripplot(x="class",
             y="age",
             data=titanic,
             ax=ax1)

sns.swarmplot(x="class",
             y="age",
             data=titanic,
             ax=ax2)

ax1.set_title('strip plot')
ax2.set_title('strip plot')

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
fig=plt.figure(figsize=(15,5)) #사이즈 설정 
ax1=fig.add_subplot(1,2,1) #(1,2,3)위치를 나타냄 1행, 2열, 1번째, 2번째 ---등
ax2=fig.add_subplot(1,3,2) 
ax3=fig.add_subplot(1,3,3)

sns.barplot(x='sex',y='survived',data=titanic,ax=ax1)

sns.barplot(x='sex',y='survived',hue='class',dodge=False,data=titanic,ax=ax3)

ax1.set_title('titanic survived - sex')
ax2.set_title('titanic survived - sex/class')
ax3.set_title('titanic survived - sex/class(stacked)')

plt.show()

# %%
sns.countplot(x='class',palette='Set1',data=titanic,ax=ax1)

sns.countplot(x='class',hue='who',palette='Set2',data=titanic,ax=ax2)

sns.countplot(x='class',hue='who',palette='Set3',dodge=False,data=titanic,ax=ax3)

ax1.set_title('titanic class')
ax2.set_title('titanic class - who')
ax3.set_title('titanic class - who(stacked)')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

titanic=sns.load_dataset('titanic')

sns.set_style('whitegrid')

fig=plt.figure(figsize=(15,5)) #사이즈 설정 
ax1=fig.add_subplot(2,2,1) #(1,2,3)위치를 나타냄 1행, 2열, 1번째, 2번째 ---등
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)
ax4=fig.add_subplot(2,2,4)

sns.boxplot(x='alive',y='age',data=titanic,ax=ax1)

sns.boxplot(x='alive',y='age',hue='sex',data=titanic, ax=ax2)

sns.violinplot(x='alive',y='age',data=titanic, ax=ax3)

sns.violinplot(x='alive',y='age',hue='sex',data=titanic, ax=ax4)

plt.show()

# %%
import folium
seoul_map=folium.Map(location=[37.55,126.98],zoom_start=12)

seoul_map.save('./seoul.html')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23188/1875112363.py in <module>
# ----> 1 import folium
#       2 seoul_map=folium.Map(location=[37.55,126.98],zoom_start=12)
#       3
#       4 seoul_map.save('./seoul.html')
#
# ModuleNotFoundError: No module named 'folium'
